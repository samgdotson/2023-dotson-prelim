# %%
from lzma import MODE_NORMAL
from xml import dom
import requests
from lxml import etree
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
def has_no_class(tag):
    return not tag.has_attr('class')

# %%
URL = "https://wiki.openmod-initiative.org/wiki/Open_Models"
BASE_URL = "https://wiki.openmod-initiative.org"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id='mw-content-text')
list_elements = results.find_all('ul')

# %%
cols= ["institution",
    "doi",
    "citation",
    "computation time comments",
    "computation time minutes",
    "contact email",
    "contact persons",
    "data availability",
    "decisions",
    "deterministic",
    "full model name",
    "georegions",
    "georesolution",
    "is suited for many scenarios",
    "license",
    "math model type",
    "math model type shortdesc",
    "model class",
    "model source public",
    "modelling software",
    "open future",
    "open source licensed",
    "processing software",
    "report references",
    "sectors",
    "source download",
    "technologies",
    "text description",
    "time resolution",
    "website",
    "objective",
    "url",
    "authors",
    "example research questions",
    "math objective",
    "network coverage",
    "number of variables"]

# %%
model_list = list_elements[-1]

# run through the list of models

frames = []
for a in model_list.find_all('a', href=True):
    
    model_name = list(a.children)[0]
    print(model_name)

    # get the URL of a model
    MODEL_URL = BASE_URL + a['href']
    print(MODEL_URL)

    
    
    
    df_list = pd.read_html(MODEL_URL)
    
    obj = df_list[3].loc[4].values[1]
    
    large_df = df_list[4]
    large_df = large_df.rename(columns={1:f'{model_name}'}).T
    large_df.columns = large_df.iloc[0]
#     large_df.columns = cols
    large_df.drop(large_df.index[0], inplace=True)
    large_df['Objective'] = obj
    large_df['URL'] = MODEL_URL
    
    frames.append(large_df)
# Out:
# AMIRIS
# https://wiki.openmod-initiative.org/wiki/AMIRIS
# ASAM
# https://wiki.openmod-initiative.org/wiki/ASAM
# AnyMOD
# https://wiki.openmod-initiative.org/wiki/AnyMOD
# Backbone
# https://wiki.openmod-initiative.org/wiki/Backbone
# Balmorel
# https://wiki.openmod-initiative.org/wiki/Balmorel
# Breakthrough Energy Model
# https://wiki.openmod-initiative.org/wiki/Breakthrough_Energy_Model
# CAPOW
# https://wiki.openmod-initiative.org/wiki/CAPOW
# CESAR-P
# https://wiki.openmod-initiative.org/wiki/CESAR-P
# Calliope
# https://wiki.openmod-initiative.org/wiki/Calliope
# CapacityExpansion
# https://wiki.openmod-initiative.org/wiki/CapacityExpansion
# DESSTinEE
# https://wiki.openmod-initiative.org/wiki/DESSTinEE
# DIETER
# https://wiki.openmod-initiative.org/wiki/DIETER
# Demod
# https://wiki.openmod-initiative.org/wiki/Demod
# Dispa-SET
# https://wiki.openmod-initiative.org/wiki/Dispa-SET
# DynPP
# https://wiki.openmod-initiative.org/wiki/DynPP
# EA-PSM Electric Arc Flash
# https://wiki.openmod-initiative.org/wiki/EA-PSM_Electric_Arc_Flash
# EA-PSM Electric Short Circuit
# https://wiki.openmod-initiative.org/wiki/EA-PSM_Electric_Short_Circuit
# ELMOD
# https://wiki.openmod-initiative.org/wiki/ELMOD
# ELTRAMOD
# https://wiki.openmod-initiative.org/wiki/ELTRAMOD
# EMLab-Generation
# https://wiki.openmod-initiative.org/wiki/EMLab-Generation
# EMMA
# https://wiki.openmod-initiative.org/wiki/EMMA
# EOLES elec
# https://wiki.openmod-initiative.org/wiki/EOLES_elec
# EOLES elecRES
# https://wiki.openmod-initiative.org/wiki/EOLES_elecRES
# ESO-X
# https://wiki.openmod-initiative.org/wiki/ESO-X
# Energy Policy Simulator
# https://wiki.openmod-initiative.org/wiki/Energy_Policy_Simulator
# Energy Transition Model
# https://wiki.openmod-initiative.org/wiki/Energy_Transition_Model
# EnergyNumbers-Balancing
# https://wiki.openmod-initiative.org/wiki/EnergyNumbers-Balancing
# EnergyRt
# https://wiki.openmod-initiative.org/wiki/EnergyRt
# EnergyScope
# https://wiki.openmod-initiative.org/wiki/EnergyScope
# Ficus
# https://wiki.openmod-initiative.org/wiki/Ficus
# FlexiGIS
# https://wiki.openmod-initiative.org/wiki/FlexiGIS
# GAMAMOD
# https://wiki.openmod-initiative.org/wiki/GAMAMOD
# GAMAMOD-DE
# https://wiki.openmod-initiative.org/wiki/GAMAMOD-DE
# GRIMSEL-FLEX
# https://wiki.openmod-initiative.org/wiki/GRIMSEL-FLEX
# Genesys
# https://wiki.openmod-initiative.org/wiki/Genesys
# GridCal
# https://wiki.openmod-initiative.org/wiki/GridCal
# HighRES
# https://wiki.openmod-initiative.org/wiki/HighRES
# JMM
# https://wiki.openmod-initiative.org/wiki/JMM
# Lemlab
# https://wiki.openmod-initiative.org/wiki/Lemlab
# LoadProfileGenerator
# https://wiki.openmod-initiative.org/wiki/LoadProfileGenerator
# MEDEAS
# https://wiki.openmod-initiative.org/wiki/MEDEAS
# MOCES
# https://wiki.openmod-initiative.org/wiki/MOCES
# Maon
# https://wiki.openmod-initiative.org/wiki/Maon
# Medea
# https://wiki.openmod-initiative.org/wiki/Medea
# Mosaik
# https://wiki.openmod-initiative.org/wiki/Mosaik
# MultiMod
# https://wiki.openmod-initiative.org/wiki/MultiMod
# NEMO
# https://wiki.openmod-initiative.org/wiki/NEMO
# NEMO (SEI)
# https://wiki.openmod-initiative.org/wiki/NEMO_(SEI)
# OMEGAlpes
# https://wiki.openmod-initiative.org/wiki/OMEGAlpes
# OSeMOSYS
# https://wiki.openmod-initiative.org/wiki/OSeMOSYS
# Oemof
# https://wiki.openmod-initiative.org/wiki/Oemof
# OnSSET
# https://wiki.openmod-initiative.org/wiki/OnSSET
# OpenTUMFlex
# https://wiki.openmod-initiative.org/wiki/OpenTUMFlex
# PLEXOS Open EU
# https://wiki.openmod-initiative.org/wiki/PLEXOS_Open_EU
# POMATO
# https://wiki.openmod-initiative.org/wiki/POMATO
# Pandapower
# https://wiki.openmod-initiative.org/wiki/Pandapower
# PowNet
# https://wiki.openmod-initiative.org/wiki/PowNet
# PowerMatcher
# https://wiki.openmod-initiative.org/wiki/PowerMatcher
# PowerSimulations.jl
# https://wiki.openmod-initiative.org/wiki/PowerSimulations.jl
# PowerSimulationsDynamics.jl
# https://wiki.openmod-initiative.org/wiki/PowerSimulationsDynamics.jl
# PowerSystems.jl
# https://wiki.openmod-initiative.org/wiki/PowerSystems.jl
# Pvlib python
# https://wiki.openmod-initiative.org/wiki/Pvlib_python
# PyLESA
# https://wiki.openmod-initiative.org/wiki/PyLESA
# PyPSA
# https://wiki.openmod-initiative.org/wiki/PyPSA
# REopt
# https://wiki.openmod-initiative.org/wiki/REopt
# Region4FLEX
# https://wiki.openmod-initiative.org/wiki/Region4FLEX
# Renpass
# https://wiki.openmod-initiative.org/wiki/Renpass
# SIREN
# https://wiki.openmod-initiative.org/wiki/SIREN
# SMS++
# https://wiki.openmod-initiative.org/wiki/SMS%2B%2B
# SciGRID gas
# https://wiki.openmod-initiative.org/wiki/SciGRID_gas
# SciGRID power
# https://wiki.openmod-initiative.org/wiki/SciGRID_power
# SimSEE
# https://wiki.openmod-initiative.org/wiki/SimSEE
# SimSES
# https://wiki.openmod-initiative.org/wiki/SimSES
# StELMOD
# https://wiki.openmod-initiative.org/wiki/StELMOD
# Switch
# https://wiki.openmod-initiative.org/wiki/Switch
# System Advisor Model (SAM)
# https://wiki.openmod-initiative.org/wiki/System_Advisor_Model_(SAM)
# TIMES
# https://wiki.openmod-initiative.org/wiki/TIMES
# TIMES Évora
# https://wiki.openmod-initiative.org/wiki/TIMES_%C3%89vora
# TIMES-PT
# https://wiki.openmod-initiative.org/wiki/TIMES-PT
# Temoa
# https://wiki.openmod-initiative.org/wiki/Temoa
# TransiEnt
# https://wiki.openmod-initiative.org/wiki/TransiEnt
# URBS
# https://wiki.openmod-initiative.org/wiki/URBS
# USENSYS
# https://wiki.openmod-initiative.org/wiki/USENSYS

# %%
model_df = pd.concat(frames, axis=0)
model_df.columns = cols
model_df.index.names = ['Model']

# %%
model_df.to_csv('esom_database.csv', encoding='utf-8')

# %% [markdown]
# # Process Data
#
# * Filter for the frameworks that have open licenses AND have open source code.

# %%
model_df = pd.read_csv('esom_database.csv', encoding='utf-8', index_col='Model')

# %%
model_df.fillna(-999, inplace=True)

# %%
len(model_df.index)
# Out:
# 83

# %%
model_df[(~(model_df['objective'] == -999))][['objective', 'citation','source download']]
# Out:
#                                                                                                                     objective  \
# Model
# AnyMOD                                                                 cost minimization by default, can set other objectives
# Backbone                                                                                                    Cost minimization
# Balmorel                                                                                                       economic costs
# Breakthrough Energy Model                                                                                       Minimize cost
# CAPOW                                                                                                       Cost minimization
# Calliope                                                 User-dependent, including financial cost, CO2, and water consumption
# CapacityExpansion                                                                                           Total system cost
# DESSTinEE                                                                        Costs, welfare, carbon emissions, fuel mixes
# DIETER                                                                                                      Cost minimization
# Demod                                            Assess domestic energy demand evolution and demand-side-management scenarios
# Dispa-SET                                                                                   Minimization of operational costs
# DynPP                                                                              operation, cost, emissions, thermal stress
# ELTRAMOD                                                                                   Minimization of total system costs
# EMMA                                                                                                        Total system cost
# EOLES elec                                            investment cost and operational costs (fixed and variable) minimization
# EOLES elecRES                                         investment cost and operational costs (fixed and variable) minimization
# ESO-X                                                                                              minimise total system cost
# Energy Transition Model                Given demand and other choices, calculate primary energy use, costs, CO2-emission etc.
# EnergyRt                                                                                                                costs
# EnergyScope                                                                        financial cost, greenhouse gases emissions
# Ficus                                                                                                                   costs
# FlexiGIS                    simualte local urban demand and supply, localise distributed storage, minimise total system costs
# GRIMSEL-FLEX                                                                               Minimization of total system costs
# Genesys                                                                                minimise levelised cost of electricity
# GridCal                                                                          Match generation to demand and minimise cost
# HighRES                                                                                    Minimization of total system costs
# MEDEAS                                                     CO2 equivalent emissions, energy, social, economic costs, RE-share
# Maon                                Economic welfare at electricity spot, electricity reserve, and emission markets in Europe
# Medea                                                                                                       Total system cost
# NEMO                                                                                     minimise average cost of electricity
# NEMO (SEI)                                                                                    Minimize total discounted costs
# OSeMOSYS                                                                             Minimise total discounted cost of system
# Oemof                                                                                                        costs, emissions
# OnSSET                                                                                                      Cost minimization
# OpenTUMFlex                                                             Cost optimal optimization and flexibility calculation
# PLEXOS Open EU                                                                                 Minimize total Generation cost
# POMATO                                                                                                      Cost minimization
# PowNet                                                                                                      Cost minimization
# PowerSimulations.jl                                                                                                Least Cost
# PyLESA                                                                                      Minimization of operational costs
# PyPSA                                                                                                       Cost minimization
# REopt                                                                                                 Minimize Lifecycle Cost
# Renpass                                                                                                        economic costs
# SIREN                                                                            Match generation to demand and minimise cost
# SMS++                                                                           in principle any, currently cost minimization
# SimSEE                                                                           minimization of the future operational cost.
# StELMOD                                                                                 Minimization of total generation cost
# Switch                                                         total cost or consumer surplus, including environmental adders
# System Advisor Model (SAM)               time series power generation, installation cost, annual operating and financial cost
# TIMES                                                                               Total discounted system cost minimisation
# TIMES Évora                                                               Minimise total discounted cost of the energy system
# TIMES-PT                                                                  Minimise total discounted cost of the energy system
# Temoa                                                                                                       Cost minimization
# URBS                                                                                 Minimise total discounted cost of system
# USENSYS                                                                                                     Cost minimization
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                    citation  \
# Model
# AnyMOD                                                                                                                                                                                                                                                                                      Göke (2020), AnyMOD - A graph-based framework for energy system modelling with high levels of renewables and sector integration, Working Paper.
# Backbone                                                                                                                                                                                                                                                  Helistö, N.; Kiviluoma, J.; Ikäheimo, J.; Rasku, T.; Rinne, E.; O’Dwyer, C.; Li, R.; Flynn, D. Backbone—An Adaptable Energy Systems Modelling Framework. Energies 2019, 12, 3388.
# Balmorel                                                                                                                                                                                                                                                                             Göransson, L. and Johnsson, F. (2013), Cost-optimized allocation of wind power investments: a Nordic-German perspective, Wind Energy, Vol. 16, Issue 4
# Breakthrough Energy Model                                                                                                                                                                                                                            Y. Xu et al., "U.S. Test System with High Spatial and Temporal Resolution for Renewable Integration Studies," 2020 IEEE Power & Energy Society General Meeting (PESGM), 2020, pp. 1-5.
# CAPOW                                                 Su, Y., Kern, J., Denaro, S., Hill, J., Re … Su, Y., Kern, J., Denaro, S., Hill, J., Reed, P., Sun, Y., Cohen, J., Characklis, G. (2020). “An open source model for quantifying risks in bulk electric power systems from spatially and temporally correlated hydrometeorological processes” Environmental Modelling and Software. Vol. 126ronmental Modelling and Software. Vol. 126
# Calliope                                                                                                                                                                                                                                                                                          Pfenninger and Pickering, (2018). Calliope: a multi-scale energy systems modelling framework. Journal of Open Source Software, 3(29), 825
# CapacityExpansion                                                                                                                                                                                                                                                                                                                                                                        https://joss.theoj.org/papers/10.21105/joss.02034#
# DESSTinEE                                                                                                                                                                                                                                                                         T. Bossmann and I. Staffell, 2016. The shape of future electricity demand: Exploring load curves in 2050s Germany and Britain. Energy, 90(20), 1317–1333.
# DIETER                                                                                                                                                                                                                                                 Zerrahn, A., Schill, W.-P. (2017): Long-run power storage requirements for high shares of renewables: review and a new model. Renewable and Sustainable Energy Reviews 79, 1518-1534
# Demod                                                                                                                                                                                                                                          Barsanti, M., Schwarz, J.S., Gérard Constantin, L.G. et al. Socio-technical modeling of smart energy systems: a co-simulation design for domestic energy demand. Energy Inform 4, 12 (2021).
# Dispa-SET                                                                                                                                                                                                                        Quoilin, S., Hidalgo Gonzalez, I., & Zucker, A. (2017). Modelling Future EU Power Systems Under High Shares of Renewables: The Dispa-SET 2.1 open-source model. Publications Office of the European Union.
# DynPP                                                                                                                                                                                                                                                                                                                                                        Modelling and simulation of a coal-fired power plant for start-up optimisation
# ELTRAMOD                                                                                                                                                                                                                                                                                                                                                  Demand Side Management in Deutschland zur Systemintegration erneuerbarer Energien
# EMMA                                                                                                                                                                                                                                                                                                                                                                                                                                   -999
# EOLES elec                                                                                                                                                                                                                                              Shirizadeh, B. & Quirion, P. (2020). Low-carbon options for French power sector: What role for renewables, nuclear energy and carbon capture and storage? Energy Economics, 105004.
# EOLES elecRES                                                                                                                                                                                                                                                          Shirizadeh, B., Perrier, Q. & Quirion, P. (2022) How sensitive are optimal fully renewable systems to technology cost uncertainty? The Energy Journal, Vol 43, No. 1
# ESO-X                                                                                                                                                                                                                     Heuberger CF, Rubin ES, Staffell I, Shah N, Mac Dowell Nclose, 2017, Power capacity expansion planning considering endogenous technology cost learning, APPLIED ENERGY, Vol: 204, Pages: 831-845, ISSN: 0306-2619
# Energy Transition Model                                                                                                                                                                                                                                                                                                                                                                            https://github.com/quintel/documentation
# EnergyRt                                                                                                                                                                                                                                                                                                                                                                                                                               -999
# EnergyScope                                                                                                                                                                                                                                                                                 Limpens G, Moret S, Jeanmart H, Maréchal F,EnergyScope TD: a novel open-source model for regional energy systems. Appl Energy 2019; Volume 255.
# Ficus                                                                                                                                                                                                                                                                                                                                                                                                                                  -999
# FlexiGIS                                                                                                                                                                                                                                                                                           GIS-based urban energy systems models and tools: Introducing a model for the optimisation of flexibilisation technologies in urban areas
# GRIMSEL-FLEX                                                                                                                                                                                                                                                                                                                                                                                                                           -999
# Genesys                                                                                                                                                                                                                                                                              Bussar et. al, 2014, Optimal Allocation and Capacity of Energy Storage Systems in a Future European Power System with 100% Renewable Energy Generation
# GridCal                                                                                                                                                                                                                                                                                                                                                                                                                                -999
# HighRES                                                                                                                                                                                                 Zeyringer, M., Price, J., Fais, B., Li, P.-H. & Sharp, E. Designing low-carbon power systems for Great Britain in 2050 that are robust to the spatiotemporal and inter-annual variability of weather. Nat. Energy 3, 395–403 (2018)
# MEDEAS                                                                                                                                                                                                                                                                                                                                                                                                                                 -999
# Maon                                                                                                                                                                                                                          Ketov, Mihail (2019). "Marktsimulationen unter Berücksichtigung der Strom-Wärme-Sektorenkopplung", Print Production, Aachener Beiträge zur Energieversorgung, volume 189, PhD thesis, RWTH Aachen University.
# Medea                                                                                                                                                                                                                                                                                                                                                                                                      https://arxiv.org/abs/2006.08009
# NEMO                                                                                                                                                                                                                                                                                                                                                                                                                                   -999
# NEMO (SEI)                                                                                                                                                                                                                                                                                                                                                                                                                   In preparation
# OSeMOSYS                                                                                                                                                                                                                                                                                                                                                                                                                               -999
# Oemof                                                                                                                                                                                                                                                                                                                                                                                                                                  -999
# OnSSET                      Mentis, Dimitrios; Welsch, Manuel; Fuso Ne … Mentis, Dimitrios; Welsch, Manuel; Fuso Nerini, Francesco; Broad, Oliver; Howells, Mark; Bazilian, Morgan; Rogner, Holger (December 2015). "A GIS-based approach for electrification planning: a case study on Nigeria". Energy for Sustainable Development. 29: 142–150. doi:10.1016/j.esd.2015.09.007. ISSN 0973-0826.10.1016/j.esd.2015.09.007. ISSN 0973-0826.
# OpenTUMFlex                                                                                                                                                                                                                                         Zade, M.; You, Z.; Kumaran Nalini, B.; Tzscheutschler, P.; Wagner, U. Quantifying the Flexibility of Electric Vehicles in Germany and California—A Case Study. Energies 2020, 13, 5617.
# PLEXOS Open EU                                                                                                                                                                                                                                                                                                                                                           http://www.sciencedirect.com/science/article/pii/S0960148115001640
# POMATO                                                                                                                                                                                                                                                                              Weinhold, Richard, and Robert Mieth. 2021. “Power Market Tool (POMATO) for the Analysis of Zonal Electricity Markets.” SoftwareX 16 (December): 100870.
# PowNet                                                                                                                                                                                                         Chowdhury, A.F.M.K., Kern, J., Dang, T.D. and Galelli, S., 2020. PowNet: A Network-Constrained Unit Commitment/Economic Dispatch Model for Large-Scale Power Systems Analysis. Journal of Open Research Software, 8(1), p.5.
# PowerSimulations.jl                                                                                                                                                                                                                                                                                                                                                                                                                    -999
# PyLESA                                                                                                                                                                                                                                                                                                                                                                                                                                 -999
# PyPSA                                                                                                                                                                                                                                                                                                                                                                                        Journal of Open Research Software, 2018, 6 (1)
# REopt                                                                                                                                                                                                                                                                                                                                                                                          https://www.nrel.gov/docs/fy14osti/61783.pdf
# Renpass                                                                                                                                                                                                                                             Wiese, F. (2015). renpass - Renewable Energy Pathways Simulation System - Open Source as an approach to meet challenges in energy modeling. Dissertation. Europa-Universität Flensburg.
# SIREN                                                                                                                                                                                                                                                                                                                                                                                                                                  -999
# SMS++                                                                                                                                                                                                                                                                                                                                                                                                                    under construction
# SimSEE                                                                                                                                                                                                                                                                                    Chaer, R. (2008.). Simulación de sistemas de energía eléctrica. Tesis de maestría. Universidad de la Republica (Uruguay). Facultad de Ingenieria.
# StELMOD                                                                                                                                                                                                     Abrell, Jan and Kunz, Friedrich (2015): Integrating Intermittent Renewable Wind Generation - A Stochastic Multi-Market Electricity Model for the European Electricity Market, Networks and Spatial Economics 15(1), pp. 117-147
# Switch                                                                                                                                                                                                                                                      J. Johnston, R. Henríquez, B. Maluenda and M. Fripp “Switch 2.0: a modern platform for planning high-renewable power systems,” Preprint, 2018. https://arxiv.org/abs/1804.05481
# System Advisor Model (SAM)                                                        Blair, N.; Dobos, A.; Freeman, J.; Neises, … Blair, N.; Dobos, A.; Freeman, J.; Neises, T.; Wagner, M.; Ferguson, T.; Gilman, P.; Janzou, S. (2014). System Advisor Model, SAM 2014.1.14: General Description. NREL/TP-6A20-61019. National Renewable Energy Laboratory. Golden, CO. Accessed October 31, 2016.ry. Golden, CO. Accessed October 31, 2016.
# TIMES                                                                                                                                                                                                                                                                                                                                    Documentation for the TIMES Model, R. Loulou, G. Goldstein, A. Kanudia, A. Lehtila, U. Remme, 2016
# TIMES Évora                                                                                                                                                                                                                                                                                                                                                                                                                            -999
# TIMES-PT                                                                                                                                                                                                                                                                                                                                                                                                                               -999
# Temoa                                                                                                                                                                                                                                                               Hunter, K., Sreepathi, S., DeCarolis, J. F. (2013). Modeling for insight using tools for energy model optimization and analysis (TEMOA). Energy Economics, 40, 339-349.
# URBS                                                                                                                                                                                                                                                                            Dorfner, Johannes (2016). "Open Source Modelling and Optimisation of Energy Infrastructure at Urban Scale", doctoral thesis, Technical University of Munich
# USENSYS                                                                                                                                                                                                                                                                                                                                                                                                                                -999
#
#                                                                              source download
# Model
# AnyMOD                                                                                  -999
# Backbone                                           https://gitlab.vtt.fi/backbone/backbone +
# Balmorel                                                  https://zenodo.org/record/823693 +
# Breakthrough Energy Model                           https://github.com/Breakthrough-Energy +
# CAPOW                                              https://github.com/romulus97/CAPOW_PY36 +
# Calliope                                      https://github.com/calliope-project/calliope +
# CapacityExpansion                    https://github.com/YoungFaithful/CapacityExpansion.jl +
# DESSTinEE                                                     http://tinyurl.com/desstinee +
# DIETER                                                                                  -999
# Demod                                                  https://github.com/epfl-herus/demod +
# Dispa-SET                        https://joinup.ec.europa.eu/software/dispaset/description +
# DynPP                                                                                   -999
# ELTRAMOD                                                                                -999
# EMMA                                                         https://neon-energie.de/emma/ +
# EOLES elec                                                                              -999
# EOLES elecRES                           https://github.com/BehrangShirizadeh/EOLES_elecRES +
# ESO-X                                                                                   -999
# Energy Transition Model                           https://github.com/quintel/documentation +
# EnergyRt                                              https://github.com/olugovoy/energyRt +
# EnergyScope                                     https://github.com/energyscope/EnergyScope +
# Ficus                                                      https://github.com/yabata/ficus +
# FlexiGIS                                          https://github.com/FlexiGIS/FlexiGIS.git +
# GRIMSEL-FLEX                                      https://github.com/arthurrinaldi/grimsel +
# Genesys                                                         http://Form%20on%20website +
# GridCal                                              https://github.com/SanPen/GridCal.git +
# HighRES                                                                                 -999
# MEDEAS                                                 http://medeas.eu/model/medeas-model +
# Maon                                                           https://apis.cloud.maon.eu/ +
# Medea                                                   https://github.com/inwe-boku/medea +
# NEMO                                                    https://git.ozlabs.org/?p=nemo.git +
# NEMO (SEI)                                 https://github.com/sei-international/NemoMod.jl +
# OSeMOSYS                                               http://github.com/OSeMOSYS/OSeMOSYS +
# Oemof                                              https://github.com/oemof/oemof/releases +
# OnSSET                                                https://github.com/KTH-dESA/PyOnSSET +
# OpenTUMFlex                                         https://github.com/tum-ewk/OpenTUMFlex +
# PLEXOS Open EU              http://wiki.openmod-initiative.org/wiki/Power_plant_portfolios +
# POMATO                                          https://github.com/richard-weinhold/pomato +
# PowNet                                      https://zenodo.org/record/3462879#.XoL6T4gzZaQ +
# PowerSimulations.jl                       https://github.com/nrel-siip/PowerSimulations.jl +
# PyLESA                                               https://github.com/andrewlyden/PyLESA +
# PyPSA                                                       https://github.com/PyPSA/PyPSA +
# REopt                                               https://github.com/NREL/REopt_Lite_API +
# Renpass                                             https://github.com/fraukewiese/renpass +
# SIREN                                                 https://github.com/ozsolarwind/siren +
# SMS++                                               https://gitlab.com/smspp/smspp-project +
# SimSEE                                            https://sourceforge.net/projects/simsee/ +
# StELMOD                                                  https://github.com/frkunz/stELMOD +
# Switch                                              https://github.com/switch-model/switch +
# System Advisor Model (SAM)                                     https://github.com/nrel/sam +
# TIMES                                           https://github.com/etsap-TIMES/TIMES_model +
# TIMES Évora                                                                             -999
# TIMES-PT                                     https://iea-etsap.org/index.php/documentation +
# Temoa                                               https://github.com/TemoaProject/temoa/ +
# URBS                                                       https://github.com/tum-ens/urbs +
# USENSYS                                                 https://github.com/usensys/usensys +

# %%
model_list = model_df[['objective', 'math model type shortdesc']]
model_list
# Out:
#                                                                                                                        objective  \
# Model
# AMIRIS                                                                                                                      -999
# ASAM                                                                                                                        -999
# AnyMOD                                                                    cost minimization by default, can set other objectives
# Backbone                                                                                                       Cost minimization
# Balmorel                                                                                                          economic costs
# Breakthrough Energy Model                                                                                          Minimize cost
# CAPOW                                                                                                          Cost minimization
# CESAR-P                                                                                                                     -999
# Calliope                                                    User-dependent, including financial cost, CO2, and water consumption
# CapacityExpansion                                                                                              Total system cost
# DESSTinEE                                                                           Costs, welfare, carbon emissions, fuel mixes
# DIETER                                                                                                         Cost minimization
# Demod                                               Assess domestic energy demand evolution and demand-side-management scenarios
# Dispa-SET                                                                                      Minimization of operational costs
# DynPP                                                                                 operation, cost, emissions, thermal stress
# EA-PSM Electric Arc Flash                                                                                                   -999
# EA-PSM Electric Short Circuit                                                                                               -999
# ELMOD                                                                                                                       -999
# ELTRAMOD                                                                                      Minimization of total system costs
# EMLab-Generation                                                                                                            -999
# EMMA                                                                                                           Total system cost
# EOLES elec                                               investment cost and operational costs (fixed and variable) minimization
# EOLES elecRES                                            investment cost and operational costs (fixed and variable) minimization
# ESO-X                                                                                                 minimise total system cost
# Energy Policy Simulator                                                                                                     -999
# Energy Transition Model                   Given demand and other choices, calculate primary energy use, costs, CO2-emission etc.
# EnergyNumbers-Balancing                                                                                                     -999
# EnergyRt                                                                                                                   costs
# EnergyScope                                                                           financial cost, greenhouse gases emissions
# Ficus                                                                                                                      costs
# FlexiGIS                       simualte local urban demand and supply, localise distributed storage, minimise total system costs
# GAMAMOD                                                                                                                     -999
# GAMAMOD-DE                                                                                                                  -999
# GRIMSEL-FLEX                                                                                  Minimization of total system costs
# Genesys                                                                                   minimise levelised cost of electricity
# GridCal                                                                             Match generation to demand and minimise cost
# HighRES                                                                                       Minimization of total system costs
# JMM                                                                                                                         -999
# Lemlab                                                                                                                      -999
# LoadProfileGenerator                                                                                                        -999
# MEDEAS                                                        CO2 equivalent emissions, energy, social, economic costs, RE-share
# MOCES                                                                                                                       -999
# Maon                                   Economic welfare at electricity spot, electricity reserve, and emission markets in Europe
# Medea                                                                                                          Total system cost
# Mosaik                                                                                                                      -999
# MultiMod                                                                                                                    -999
# NEMO                                                                                        minimise average cost of electricity
# NEMO (SEI)                                                                                       Minimize total discounted costs
# OMEGAlpes                                                                                                                   -999
# OSeMOSYS                                                                                Minimise total discounted cost of system
# Oemof                                                                                                           costs, emissions
# OnSSET                                                                                                         Cost minimization
# OpenTUMFlex                                                                Cost optimal optimization and flexibility calculation
# PLEXOS Open EU                                                                                    Minimize total Generation cost
# POMATO                                                                                                         Cost minimization
# Pandapower                                                                                                                  -999
# PowNet                                                                                                         Cost minimization
# PowerMatcher                                                                                                                -999
# PowerSimulations.jl                                                                                                   Least Cost
# PowerSimulationsDynamics.jl                                                                                                 -999
# PowerSystems.jl                                                                                                             -999
# Pvlib python                                                                                                                -999
# PyLESA                                                                                         Minimization of operational costs
# PyPSA                                                                                                          Cost minimization
# REopt                                                                                                    Minimize Lifecycle Cost
# Region4FLEX                                                                                                                 -999
# Renpass                                                                                                           economic costs
# SIREN                                                                               Match generation to demand and minimise cost
# SMS++                                                                              in principle any, currently cost minimization
# SciGRID gas                                                                                                                 -999
# SciGRID power                                                                                                               -999
# SimSEE                                                                              minimization of the future operational cost.
# SimSES                                                                                                                      -999
# StELMOD                                                                                    Minimization of total generation cost
# Switch                                                            total cost or consumer surplus, including environmental adders
# System Advisor Model (SAM)                  time series power generation, installation cost, annual operating and financial cost
# TIMES                                                                                  Total discounted system cost minimisation
# TIMES Évora                                                                  Minimise total discounted cost of the energy system
# TIMES-PT                                                                     Minimise total discounted cost of the energy system
# Temoa                                                                                                          Cost minimization
# TransiEnt                                                                                                                   -999
# URBS                                                                                    Minimise total discounted cost of system
# USENSYS                                                                                                        Cost minimization
#
#                                                                                                                                                                                                                                                                   math model type shortdesc
# Model
# AMIRIS                                                                                                                                                                                                               algorithms for market clearing and agent-specific bidding strategies +
# ASAM                                                                                                                                                                                                                                                                                   -999
# AnyMOD                                                                                                                                                                                                                                                     Continuous Linear Optimization +
# Backbone                                                                                                               The model minimizes the objective function and includes constraints related to energy balance, unit operation, transfers, system operation, portfolio design, etc. +
# Balmorel                                                                                                                                                                                                                                                                               -999
# Breakthrough Energy Model                                                                                                                                                                                                            The Breakthrough Energy Model runs DCOPF simulations +
# CAPOW                                                                                                                                                                                                                Iterative mixed-integer program, with user defined operating horizon +
# CESAR-P                                                                                                                                                                                                                                                                                -999
# Calliope                                                                                                                                                                                                                                                                               -999
# CapacityExpansion                                                                                                                                                                                              Optimization, Linear optimization model input-data depending energy system +
# DESSTinEE                                                                                                            Annual projection: simple arithmetic Hourly load curve production: partial decomposition Electricty system dispatch: Merit order stack with transmission constraints +
# DIETER                                                Linear cost minimization problem. Decision variables include investment and dispatch of generation, storage, DSM and different sector coupling options including vehicle-grid interactions in both wholesale and balancing markets. +
# Demod                                                                                                                                                                                                                          First order and semi- Markov-chain Monte Carlo simulation. +
# Dispa-SET                                                                                                                                                                                                       From the same dataset, the model can be expressed as a MILP or LP problem +
# DynPP                                                                                                                                                                                                                                                             physical-equation-based +
# EA-PSM Electric Arc Flash                                                                                                                                                                                                                                                              -999
# EA-PSM Electric Short Circuit                                                                                                                                                                                                                                                          -999
# ELMOD                                                                                                                                                                                                                                                                                  -999
# ELTRAMOD                                                                                  Linear optimization model. Decision variables include investment and dispatch of generation, storage, DSM and different sector coupling options including both wholesale and balancing markets. +
# EMLab-Generation                                                                                                                                                                                                                                                                       -999
# EMMA                                                                                                                                                                                                                                                                       Linear program +
# EOLES elec                                                                                                                                                                      Simultaneous optimization of dispatch and investment (linear programming), solved in CPLEX solver of GAMS +
# EOLES elecRES                                                                                                                                                                    Simultaneous optimization of dispatch and investment (linar programming), solved in CPLEX solver of GAMS +
# ESO-X                                                                                                                                                                                                                                                                                MILP +
# Energy Policy Simulator                                                                                                                                                     Annual forward simulating model with some investment optimization and full accounting of policy interactions. +
# Energy Transition Model                                                                                                                                                                      The ETM is based on an energy graph where nodes can convert one type of energy into another. +
# EnergyNumbers-Balancing                                                                                                                                                                                                                                                                -999
# EnergyRt                                                                                                                                                                                                                                     linear, cost-minimizing, partial equilibrium +
# EnergyScope                                                                                                                                                                                                                           Linear programming (43 equations fully documented). +
# Ficus                                                                                                                                                                                                                                                                                  -999
# FlexiGIS                                                                                                                                                                                                                                    Modelling and optimisation mathematical model +
# GAMAMOD                                                                                                                                                                                                                                                                                -999
# GAMAMOD-DE                                                                                                                                                                                                                                                                             -999
# GRIMSEL-FLEX                                                                                                                                                                                                                                      Quadratic dipatch sector-coupling model +
# Genesys                                                                                           optimisation of system combination with evolutionary strategy simulation of operation with hierarchical management strategy and linear load balancing between regions (network simplex) +
# GridCal                                                                                                                                                                                            Object oriented structures -> intermediate objects holding arrays -> Numerical modules +
# HighRES                                                                                                                                                                                                                                                                                -999
# JMM                                                                                                                                                                                                                                                                                    -999
# Lemlab                                                                                                                  Agents: intertemporal convex optimization Markets: (iterative) double-sided auctions, p2p clearing Forecasting: naive, deterministic forecasting, neural networks +
# LoadProfileGenerator                                                                                                                                                                                                                                                                   -999
# MEDEAS                                                                                                                                                                                                                                                          System dynamics. Top-down +
# MOCES                                                                                                                                                                                                         HDAE (Hybrid Differential Equations) combined with an agent-based approach. +
# Maon                                                                                                                                                                                                                                                                                   -999
# Medea                                                                                                                                                                                                                                                                                  -999
# Mosaik                                                                                                                                                                                                                                                                                 -999
# MultiMod                                                                                                                                                                                       Generalized Nash Equilibrium (GNE) model formulated as a Mixed Complementarity Model (MCP) +
# NEMO                                                                                                      Optimisations are carried out using a single-objective evaluation function (with penalties). The search space (of generator capacities) is searched using the CMA-ES algorithm. +
# NEMO (SEI)                                                                                                                                                                                                                           Constrained cost optimization with perfect foresight +
# OMEGAlpes                                                                                                                                                                                                                                                                              -999
# OSeMOSYS                                                                                                                                                                                                                Linear optimisation (with an option of mixed-integer programming) +
# Oemof                                                                                                                                                                                                                                                        https://oemof.org/libraries/ +
# OnSSET                                                                                                                                                                                                                                                                                 -999
# OpenTUMFlex                                                                                                                                                                                                                                                                            -999
# PLEXOS Open EU                                                                                                                                                                                                          Least Cost Optimization, Can be run in MIP or linear relaxed mode +
# POMATO                                                                                                                                                                                Linear Economic Dispatch. Linear Optimal Power Flow. Linear Security Constrained Optimal Power Flow +
# Pandapower                                                                                                                                                                                                                                                                             -999
# PowNet                                                                                                                                                                                             Mixed Integer Linear Program (MILP), DC Power Flow, Unit Commitment, Economic Dispatch +
# PowerMatcher                                                                                                                                                                                                                                                                           -999
# PowerSimulations.jl                                                                                                                                                             Principal application is sequential quasi-static system optimization problems (production cost modeling). +
# PowerSimulationsDynamics.jl                                                        PowerSimulationsDynamics.jl enables transient stability analysis of power systems through differential-algebraic equations and with forward differentiation to enable small-signal stability analysis. +
# PowerSystems.jl                                                                                                                                                                                    PowerSystems.jl includes basic power flow and network matrix calculation capabilities. +
# Pvlib python                                                                                                                                                                                                                                                                           -999
# PyLESA                                                                                                                                                                                                                                                                                 -999
# PyPSA                                                                                                                                                                                                          Non-linear power flow; linear optimal power flow / investment optimisation +
# REopt                                                                                                                                                                                                                                                        Mixed Integer Linear Program +
# Region4FLEX                                                                                                                                                                                                                                                                            -999
# Renpass                                                                                                                                                                  Minimization of costs for each time step (optimization) within the limits of a given infrastructure (simulation) +
# SIREN                                                                                                                                                                        User NREL SAM models to estimate hourly renewable generation for a range/number of renewable energy stations +
# SMS++                                                                                                                                                                                                in principle any optimization model, particular emphasis on decomposition approaches +
# SciGRID gas                                                                                                                                                                                                                                                                            -999
# SciGRID power                                                                                                                   We consider a topological graph (V,L) as a mathematical structure that consists of a set V of vertices and a set L of nonempty subsets of V called links. +
# SimSEE                                                                                                                  Optimal Stochastic Dynamic Programming solver for computation of the operational Policy and a Monte Carlo style simulator of the system using the computed Policy +
# SimSES                                                                                                                                                                                                           Power flow and state of charge calculation based on time series profiles +
# StELMOD                                                                                                                             Mixed integer linear optimization for separate electricity markets (dayahead, intraday, congestion management) linked by a rolling planning procedure +
# Switch                                                                                                                                                                                                                                            intertemporal mathematical optimization +
# System Advisor Model (SAM)                                                                                                                                                       Time series simulation of power system performance coupled with annual pro forma cash flow calculations. +
# TIMES                                                                                                                                                                          Partial equilibrium, least cost optimisation, with MIP, NLP options. Perfect foresight and myopic options. +
# TIMES Évora                                                                                                                                                                                                                                                                            -999
# TIMES-PT                                                                                                                                                                                                                                                                               -999
# Temoa                                                                               The model objective is to minimize the present cost of energy supply by deploying and utilizing energy technologies and commodities over time to meet a set of exogenously specified end-use demands. +
# TransiEnt                      Models in the library are based on differential algebraic equations and are solved using a variable step solver. By using the object oriented Modelica language the library allows an investigation of different timescales and levels of physical detail. +
# URBS                                                                                                                                                                                                                 Linear optimization model of a user-defined reference energy system. +
# USENSYS                                                                                                                                                                                                                                                                Linear programming +

# %% [markdown]
# model_list.style.to_latex("2023-dotson-prelim/docs/tables/esom_database.tex")

# %%
"cost" in model_list.loc['DESSTinEE', 'objective'].lower()
# Out:
# True

# %%
model_df.columns
# Out:
# Index(['institution', 'doi', 'citation', 'computation time comments',
#        'computation time minutes', 'contact email', 'contact persons',
#        'data availability', 'decisions', 'deterministic', 'full model name',
#        'georegions', 'georesolution', 'is suited for many scenarios',
#        'license', 'math model type', 'math model type shortdesc',
#        'model class', 'model source public', 'modelling software',
#        'open future', 'open source licensed', 'processing software',
#        'report references', 'sectors', 'source download', 'technologies',
#        'text description', 'time resolution', 'website', 'objective', 'url',
#        'authors', 'example research questions', 'math objective',
#        'network coverage', 'number of variables'],
#       dtype='object')

# %%
other_models = [
"REMix", # done
"PRIMES",  # added
"MARKAL", # deprecated, now TIMES
"METIS", # done
"ENSYSI",
"OSeMOSYS", #done
"SimREN", # EnergyPLAN
"NEMS", #done
"POLES",
"OPERA", #done
"EnergyPLAN", #done
"IWES",
"ESME", #done
"STREAM", # EnergyPLAN
"ETM", #done
"LEAP", # EnergyPLAN
"E4Cast", # EnergyPLAN
"DynEMo",
"IKARUS", # EnergyPLAN
]

# %%
has_openmod_entry = [(i in model_df.index) for i in other_models]
for m,b in zip(other_models, has_openmod_entry):
    print(m,b)
# Out:
# REMix False
# PRIMES False
# MARKAL False
# METIS False
# ENSYSI False
# OSeMOSYS True
# SimREN False
# NEMS False
# POLES False
# OPERA False
# EnergyPLAN False
# IWES False
# ESME False
# STREAM False
# ETM False
# LEAP False
# E4Cast False
# DynEMo False
# IKARUS False

# %% [markdown]
# # Check the latex table

# %%
df = pd.read_csv("table_check.txt", delimiter='&', skiprows=3)

# %%
df.columns
# Out:
# Index(['Model ', '   Citation   ', '   math model type   ', '  MILP  ',
#        '   Objective   ', ' Transmission ', ' Heat ', ' Electric ',
#        ' Transport', ' Investment ', ' Physical ', ' Forecasting ', ' Agent  ',
#        '   Public   '],
#       dtype='object')

# %%
cols = ['Model ', '   Citation   ', '   math model type   ', '  MILP  ',
       '   Objective   ', ' Transmission ', ' Heat ', ' Electric ',
       ' Transport', ' Investment ', ' Physical ', ' Forecasting ', ' Agent  ', 'Uncertainty',
       '   Public   ']
df['Uncertainty'] = np.nan
df = df[cols]
df
# Out:
#                                 Model   \
# 0                             % JMM
# 1                    % PowerMatcher
# 2                         % USENSYS
# 3                         % GAMAMOD
# 4                      % NEMO (SEI)
# 5                       % OMEGAlpes
# 6             % PowerSimulations.jl
# 7                     % Region4FLEX
# 8                     % TIMES Évora
# 9                        % TIMES-PT
# 10                          AnyMOD
# 11                        Backbone
# 12                        Balmorel
# 13                        Calliope
# 14               CapacityExpansion
# 15                          DIETER
# 16                        Dispa-SET
# 17                           ELMOD
# 18                        ELTRAMOD
# 19                            EMMA
# 20                        % ENSYSI
# 21                            ESME
# 22                            ESO-X
# 23                        EnergyRt
# 24                      EnergyScope
# 25                           Ficus
# 26                       GAMAMOD-DE
# 27                            GenX
# 28                     GRIMSEL-FLEX
# 29                         HighRES
# 30                          MARKAL
# 31                           METIS
# 32                           Medea
# 33                           OPERA
# 34                        OSeMOSYS
# 35                          OnSSET
# 36                          PLEXOS
# 37                           POLES
# 38                          POMATO
# 39                           PyPSA
# 40                           REMix
# 41                           REopt
# 42                           % SMS
# 43                         StELMOD
# 44                          Switch
# 45                           TIMES
# 46                           Temoa
# 47                            URBS
# 48                          % DynPP
# 49      % EA-PSM Electric Arc Flash
# 50  % EA-PSM Electric Short Circuit
# 51                           % NEMO
# 52        Breakthrough Energy Model
# 53                       EOLES elec
# 54                        FlexiGIS
# 55                         Genesys
# 56                         GridCal
# 57                           Oemof
# 58                     OpenTUMFlex
# 59                          PRIMES
# 60                          PowNet
# 61                         Renpass
# 62                          SimSEE
# 63                           % Maon
# 64                          MEDEAS
# 65                        MultiMod
# 66                            NEMS
# 67            LoadProfileGenerator
# 68        % Energy Policy Simulator
# 69        % EnergyNumbers-Balancing
# 70    % PowerSimulationsDynamics.jl
# 71                % PowerSystems.jl
# 72                           CAPOW
# 73                          CESAR-P
# 74                        DESSTinEE
# 75                            Demod
# 76                 EMLab-Generation
# 77                      EnergyPLAN
# 78          Energy Transition Model
# 79                      Pandapower
# 80                           Pvlib
# 81                          PyLESA
# 82                              SAM
# 83                    SciGRID power
# 84                          SimSES
# 85                       TransiEnt
# 86                          AMIRIS
# 87                            ASAM
# 88                          Lemlab
# 89                           MOCES
# 90                          Mosaik
# 91                         % SIREN
# 92                    % SciGRID gas
#
#                                                                                         Citation     \
# 0                                                                                              -
# 1                                                                                              -
# 2                                                                                           Cost
# 3                                                                                              -
# 4                                                                Minimize total discounted costs
# 5                                                                                              -
# 6                                                                                     Least Cost
# 7                                                                                              -
# 8                                            Minimise total discounted cost of the energy system
# 9                                            Minimise total discounted cost of the energy system
# 10                                                                  \cite{goke_graph-based_2021}
# 11                                                         \cite{helisto_backboneadaptable_2019}
# 12                                                          \cite{goransson_cost-optimized_2013}
# 13                                                               \cite{pfenninger_calliope_2018}
# 14                                                         \cite{kuepper_capacityexpansion_2020}
# 15                                                                  \cite{zerrahn_long-run_2017}
# 16                                                                 \cite{quoilin_modelling_2017}
# 17                                                                    \cite{leuthold_elmod_2008}
# 18                                                                     \cite{ladwig_demand_2018}
# 19                                                                    \cite{hirth_european_2021}
# 20                                                                \cite{limpens_energyscope_2019}
# 21                                                                  \cite{heaton_modelling_2014}
# 22                                                                   \cite{heuberger_power_2017}
# 23                                                                  \cite{lugovoy_energyrt_2022}
# 24                                                               \cite{limpens_energyscope_2019}
# 25                                                                \cite{atabay_open-source_2017}
# 26                                                                  \cite{hauser_modelling_2019}
# 27                                                                      \cite{jenkins_genx_2022}
# 28                                                                      \cite{rinaldi_what_2022}
# 29                                                               \cite{zeyringer_designing_2018}
# 30                                                              \cite{loulou_documentation_2004}
# 31                                                                  \cite{sakellaris_metis_2018}
# 32                                                                       \cite{wehrle_cost_2021}
# 33                                                                 \cite{van_stralen_opera_2021}
# 34                                                                  \cite{howells_osemosys_2011}
# 35                                                                  \cite{mentis_gis-based_2015}
# 36                                                                 \cite{deane_quantifying_2015}
# 37                                                                   \cite{vandyck_global_2016}
# 38                                                                   \cite{weinhold_power_2021}
# 39                                                                       \cite{brown_pypsa_2018}
# 40                                                                   \cite{gils_integrated_2017}
# 41                                                                  \cite{simpkins_reopt_nodate}
# 42                                                                  \cite{the_sms_team_sms_2022}
# 43                                                                \cite{abrell_integrating_2015}
# 44                                                                   \cite{johnston_switch_2019}
# 45                                                              \cite{loulou_documentation_2016}
# 46                                                                   \cite{hunter_modeling_2013}
# 47                                                                      \cite{dorfner_open_2015}
# 48                                                    operation, cost, emissions, thermal stress
# 49                                                                                             -
# 50                                                                                             -
# 51                                                          minimise average cost of electricity
# 52                                                                             \cite{xu_us_2020}
# 53                                                                    \cite{shirizadeh_how_2022}
# 54                                                                 \cite{alhamwi_gis-based_2017}
# 55                                                                    \cite{bussar_optimal_2014}
# 56                                                                      \cite{vera_gridcal_2022}
# 57                                                                      \cite{hilpert_open_2018}
# 58                                                                  \cite{zade_quantifying_2020}
# 59                                                                 \cite{antoniou_decision_1999}
# 60                                                                  \cite{chowdhury_pownet_2020}
# 61                                                              \cite{frauke_wiese_renpass_2015}
# 62                                                                  \cite{chaer_simulacion_2008}
# 63     Economic welfare at electricity spot, electricity reserve, and emission markets in Europe
# 64                                                             \cite{capellan-perez_medeas_2020}
# 65                                                                   \cite{huppmann_market_2014}
# 66                                                                   \cite{nalley_national_2019}
# 67                                                               \cite{pflugradt_modelling_2016}
# 68                                                                                             -
# 69                                                                                             -
# 70                                                                                             -
# 71                                                                                             -
# 72                                                                           \cite{su_open_2020}
# 73                                             \cite{leoniefierz_hues-platformcesar-p-core_2021}
# 74                                                                     \cite{bosmann_shape_2015}
# 75                                                          \cite{barsanti_socio-technical_2021}
# 76                                                            \cite{richstein_cross-border_2014}
# 77                                                                    \cite{lund_energyplan_2021}
# 78                                                                       \cite{quintel_etm_2022}
# 79                                                                \cite{thurner_pandapower_2018}
# 80                                                                    \cite{holmgren_pvlib_2018}
# 81                                                                      \cite{lyden_pylesa_2021}
# 82                                                                      \cite{blair_system_2014}
# 83                                                                   \cite{matke_structure_2017}
# 84                                                                    \cite{naumann_simses_2017}
# 85                                                                   \cite{andresen_status_2015}
# 86                                                                   \cite{nitsch_economic_2021}
# 87                                                                \cite{glismann_ancillary_2021}
# 88                                                                   \cite{zade_satisfying_2022}
# 89                                                                 \cite{exel_multi-domain_2015}
# 90                                                                   \cite{ofenloch_mosaik_2022}
# 91                                                  \cite{sustainable_energy_now_renewable_2016}
# 92                                                                                             -
#
#                              math model type             MILP    \
# 0                                          -              nan
# 1                                          -              nan
# 2                               Optimization              nan
# 3                              Optimization               nan
# 4                              Optimization               nan
# 5                              Optimization               nan
# 6                              Optimization               nan
# 7                              Optimization               nan
# 8                              Optimization               nan
# 9                              Optimization               nan
# 10                             Optimization        \checkmark
# 11                             Optimization        \checkmark
# 12                             Optimization        \checkmark
# 13                             Optimization        \checkmark
# 14                             Optimization        \checkmark
# 15                             Optimization        \checkmark
# 16                             Optimization        \checkmark
# 17                             Optimization        \checkmark
# 18                             Optimization        \checkmark
# 19                             Optimization        \checkmark
# 20                             Optimization        \checkmark
# 21                             Optimization        \checkmark
# 22                             Optimization        \checkmark
# 23                             Optimization        \checkmark
# 24                             Optimization        \checkmark
# 25                             Optimization        \checkmark
# 26                              Optimization       \checkmark
# 27                             Optimization        \checkmark
# 28                             Optimization        \checkmark
# 29                             Optimization        \checkmark
# 30                             Optimization        \checkmark
# 31                             Optimization        \checkmark
# 32                             Optimization        \checkmark
# 33                             Optimization        \checkmark
# 34                             Optimization        \checkmark
# 35                             Optimization        \checkmark
# 36                             Optimization        \checkmark
# 37                             Optimization        \checkmark
# 38                             Optimization        \checkmark
# 39                                Optimization     \checkmark
# 40                             Optimization        \checkmark
# 41                             Optimization        \checkmark
# 42                             Optimization        \checkmark
# 43                             Optimization        \checkmark
# 44                             Optimization        \checkmark
# 45                             Optimization        \checkmark
# 46                             Optimization        \checkmark
# 47                             Optimization        \checkmark
# 48             Optimization  and Simulation               nan
# 49             Optimization  and Simulation               nan
# 50             Optimization  and Simulation               nan
# 51             Optimization  and Simulation               nan
# 52             Optimization  and Simulation               nan
# 53             Optimization  and Simulation               nan
# 54             Optimization  and Simulation               nan
# 55             Optimization  and Simulation               nan
# 56             Optimization  and Simulation               nan
# 57             Optimization  and Simulation        \checkmark
# 58             Optimization  and Simulation               nan
# 59             Optimization  and Simulation               nan
# 60             Optimization  and Simulation               nan
# 61             Optimization  and Simulation               nan
# 62             Optimization  and Simulation               nan
# 63     Optimization , Simulation  and Other               nan
# 64                                    Other               nan
# 65                                    Other               nan
# 66                                    Other               nan
# 67                                Simulation              nan
# 68                               Simulation               nan
# 69                               Simulation               nan
# 70                               Simulation               nan
# 71                               Simulation               nan
# 72                               Simulation               nan
# 73                               Simulation               nan
# 74                               Simulation               nan
# 75                               Simulation               nan
# 76                               Simulation               nan
# 77                               Simulation
# 78                               Simulation               nan
# 79                               Simulation               nan
# 80                               Simulation               nan
# 81                               Simulation               nan
# 82                               Simulation               nan
# 83                               Simulation               nan
# 84                               Simulation               nan
# 85                               Simulation               nan
# 86              Simulation  and Agent-based               nan
# 87              Simulation  and Agent-based               nan
# 88              Simulation  and Agent-based               nan
# 89              Simulation  and Agent-based               nan
# 90              Simulation  and Agent-based               nan
# 91                    Simulation  and Other               nan
# 92                    Simulation  and Other               nan
#
#                                                                                                                                                                                                            Objective     \
# 0                                                                                                                                                                                                                  -
# 1                                                                                                                                                                                                                  -
# 2                                                                                                                                                                                                                  -
# 3                                                                                                                                                                                                                  -
# 4                                                                                                                                                                                                     In preparation
# 5                                                                                                                                                                                                                  -
# 6                                                                                                                                                                                                                  -
# 7                                                                                                                                                                                                                  -
# 8                                                                                                                                                                                                                  -
# 9                                                                                                                                                                                                                  -
# 10                                                                                                                                                                                                              Cost
# 11                                                                                                                                                                                                              Cost
# 12                                                                                                                                                                                                              Cost
# 13                                                                                                                                                                                                              Cost
# 14                                                                                                                                                                                                              Cost
# 15                                                                                                                                                                                                              Cost
# 16                                                                                                                                                                                                              Cost
# 17                                                                                                                                                                                                           Welfare
# 18                                                                                                                                                                                                              Cost
# 19                                                                                                                                                                                                                Cost
# 20                                                                                                                                                                                                              Cost
# 21                                                                                                                                                                                                              Cost
# 22                                                                                                                                                                                                              Cost
# 23                                                                                                                                                                                                              Cost
# 24                                                                                                                                                                                                   Cost, \acs{ghg}
# 25                                                                                                                                                                                                              Cost
# 26                                                                                                                                                                                                              Cost
# 27                                                                                                                                                                                                              Cost
# 28                                                                                                                                                                                                              Cost
# 29                                                                                                                                                                                                              Cost
# 30                                                                                                                                                                                                              Cost
# 31                                                                                                                                                                                                              Cost
# 32                                                                                                                                                                                                              Cost
# 33                                                                                                                                                                                                              Cost
# 34                                                                                                                                                                                                              Cost
# 35                                                                                                                                                                                                              Cost
# 36                                                                                                                                                                                                              Cost
# 37                                                                                                                                                                                                              Cost
# 38                                                                                                                                                                                                              Cost
# 39                                                                                                                                                                                                              Cost
# 40                                                                                                                                                                                                              Cost
# 41                                                                                                                                                                                                              Cost
# 42                                                                                                                                                                                                              Cost
# 43                                                                                                                                                                                                              Cost
# 44                                                                                                                                                                                                              Cost
# 45                                                                                                                                                                                                     Cost, Welfare
# 46                                                                                                                                                                                                              Cost
# 47                                                                                                                                                                                                              Cost
# 48                                                                                                                                    Modelling and simulation of a coal-fired power plant for start-up optimisation
# 49                                                                                                                                                                                                                 -
# 50                                                                                                                                                                                                                 -
# 51                                                                                                                                                                                                                 -
# 52                                                                                                                                                                                                              Cost
# 53                                                                                                                                                                                                              Cost
# 54                                                                                                                                                                                                              Cost
# 55                                                                                                                                                                                                              Cost
# 56                                                                                                                                                                                                              Cost
# 57                                                                                                                                                                                                              Cost
# 58                                                                                                                                                                                                              Cost
# 59                                                                                                                                                                                                              Cost
# 60                                                                                                                                                                                                              Cost
# 61                                                                                                                                                                                                              Cost
# 62                                                                                                                                                                                                              Cost
# 63     Ketov, Mihail (2019). "Marktsimulationen unter Berücksichtigung der Strom-Wärme-Sektorenkopplung", Print Production, Aachener Beiträge zur Energieversorgung, volume 189, PhD thesis, RWTH Aachen University.
# 64                                                                                                                                                                                                                 -
# 65                                                                                                                                                                                                                 -
# 66                                                                                                                                                                                                                 -
# 67                                                                                                                                                                                                                 -
# 68                                                                                                                                                                                                                 -
# 69                                                                                                                                                                                                                 -
# 70                                                                                                                                                                                                                 -
# 71                                                                                                                                                                                                                 -
# 72                                                                                                                                                                                                              Cost
# 73                                                                                                                                                                                                                 -
# 74                                                                                                                                                                                                    Usage forecast
# 75                                                                                                                                                                                                    Usage forecast
# 76                                                                                                                                                                                                                 -
# 77                                                                                                                                                                                                              Cost
# 78                                                                                                                                                                                                                 -
# 79                                                                                                                                                                                                                 -
# 80                                                                                                                                                                                                                 -
# 81                                                                                                                                                                                                              Cost
# 82                                                                                                                                                                                              Usage forecast, Cost
# 83                                                                                                                                                                                                                 -
# 84                                                                                                                                                                                                                 -
# 85                                                                                                                                                                                                                 -
# 86                                                                                                                                                                                                                 -
# 87                                                                                                                                                                                                                 -
# 88                                                                                                                                                                                                                 -
# 89                                                                                                                                                                                                                 -
# 90                                                                                                                                                                                                                 -
# 91                                                                                                                                                                                                              Cost
# 92                                                                                                                                                                                                                 -
#
#     Transmission          Heat       Electric      Transport   Investment   \
# 0            nan           nan            nan           nan           nan
# 1            nan           nan            nan           nan           nan
# 2            nan           nan            nan           nan           nan
# 3            nan           nan            nan           nan           nan
# 4            nan           nan            nan           nan           nan
# 5            nan           nan            nan           nan           nan
# 6            nan           nan            nan           nan           nan
# 7            nan           nan            nan           nan           nan
# 8            nan           nan            nan           nan           nan
# 9            nan           nan            nan           nan           nan
# 10                  \checkmark     \checkmark                  \checkmark
# 11    \checkmark    \checkmark     \checkmark    \checkmark    \checkmark
# 12    \checkmark                   \checkmark                  \checkmark
# 13                  \checkmark     \checkmark    \checkmark    \checkmark
# 14    \checkmark                   \checkmark                  \checkmark
# 15                                 \checkmark                  \checkmark
# 16    \checkmark                   \checkmark                  \checkmark
# 17    \checkmark                   \checkmark                   \checkmark
# 18                                 \checkmark                  \checkmark
# 19                                 \checkmark                  \checkmark
# 20           nan    \checkmark     \checkmark    \checkmark           nan
# 21                  \checkmark     \checkmark    \checkmark    \checkmark
# 22                                 \checkmark                  \checkmark
# 23                                 \checkmark                  \checkmark
# 24                  \checkmark     \checkmark    \checkmark    \checkmark
# 25                                 \checkmark                  \checkmark
# 26                                 \checkmark                  \checkmark
# 27   \checkmark                    \checkmark                  \checkmark
# 28                  \checkmark     \checkmark                  \checkmark
# 29                  \checkmark     \checkmark                  \checkmark
# 30                  \checkmark     \checkmark    \checkmark    \checkmark
# 31    \checkmark    \checkmark     \checkmark                  \checkmark
# 32                                 \checkmark                  \checkmark
# 33    \checkmark    \checkmark     \checkmark                  \checkmark
# 34                  \checkmark     \checkmark    \checkmark    \checkmark
# 35    \checkmark                   \checkmark                  \checkmark
# 36                                 \checkmark                  \checkmark
# 37                                 \checkmark                  \checkmark
# 38    \checkmark    \checkmark     \checkmark
# 39    \checkmark    \checkmark     \checkmark    \checkmark    \checkmark
# 40    \checkmark    \checkmark     \checkmark    \checkmark    \checkmark
# 41                  \checkmark     \checkmark                  \checkmark
# 42           nan           nan            nan           nan           nan
# 43    \checkmark                   \checkmark                  \checkmark
# 44    \checkmark    \checkmark     \checkmark    \checkmark    \checkmark
# 45                  \checkmark     \checkmark                  \checkmark
# 46                  \checkmark     \checkmark    \checkmark    \checkmark
# 47           nan           nan            nan           nan           nan
# 48           nan           nan            nan           nan           nan
# 49           nan           nan            nan           nan           nan
# 50           nan           nan            nan           nan           nan
# 51           nan           nan            nan           nan           nan
# 52           nan           nan            nan           nan           nan
# 53           nan           nan            nan           nan           nan
# 54           nan           nan            nan           nan           nan
# 55           nan           nan            nan           nan           nan
# 56           nan           nan            nan           nan           nan
# 57           nan           nan            nan           nan           nan
# 58           nan           nan            nan           nan           nan
# 59           nan           nan            nan           nan           nan
# 60           nan           nan            nan           nan           nan
# 61           nan           nan            nan           nan           nan
# 62           nan           nan            nan           nan           nan
# 63           nan           nan            nan           nan           nan
# 64           nan           nan            nan           nan           nan
# 65           nan           nan            nan           nan           nan
# 66           nan           nan            nan           nan           nan
# 67           nan           nan            nan           nan           nan
# 68           nan           nan            nan           nan           nan
# 69           nan           nan            nan           nan           nan
# 70           nan           nan            nan           nan           nan
# 71           nan           nan            nan           nan           nan
# 72           nan           nan            nan           nan           nan
# 73           nan           nan            nan           nan           nan
# 74           nan           nan            nan           nan           nan
# 75           nan           nan            nan           nan           nan
# 76           nan           nan            nan           nan           nan
# 77    \checkmark    \checkmark     \checkmark    \checkmark    \checkmark
# 78           nan           nan            nan           nan           nan
# 79           nan           nan            nan           nan           nan
# 80           nan           nan            nan           nan           nan
# 81           nan           nan            nan           nan           nan
# 82           nan           nan            nan           nan           nan
# 83           nan           nan            nan           nan           nan
# 84           nan           nan            nan           nan           nan
# 85           nan           nan            nan           nan           nan
# 86           nan           nan            nan           nan           nan
# 87           nan           nan            nan           nan           nan
# 88           nan           nan            nan           nan           nan
# 89           nan           nan            nan           nan           nan
# 90           nan           nan            nan           nan           nan
# 91           nan           nan            nan           nan           nan
# 92           nan           nan            nan           nan           nan
#
#        Physical   Forecasting        Agent    Uncertainty          Public
# 0           nan           nan           nan           NaN         \xmark
# 1           nan           nan           nan           NaN     \checkmark
# 2           nan           nan           nan           NaN     \checkmark
# 3           nan           nan           nan           NaN         \xmark
# 4           nan           nan           nan           NaN     \checkmark
# 5           nan           nan           nan           NaN     \checkmark
# 6           nan           nan           nan           NaN     \checkmark
# 7           nan           nan           nan           NaN         \xmark
# 8           nan           nan           nan           NaN     \checkmark
# 9           nan           nan           nan           NaN     \checkmark
# 10                                                    NaN     \checkmark
# 11                 \checkmark                         NaN     \checkmark
# 12                                                    NaN     \checkmark
# 13                                                    NaN     \checkmark
# 14                                                    NaN     \checkmark
# 15                                                    NaN     \checkmark
# 16                                                    NaN     \checkmark
# 17                                                    NaN     \checkmark
# 18                                                    NaN
# 19                                                    NaN     \checkmark
# 20          nan           nan           nan           NaN     \checkmark
# 21                                                    NaN
# 22                         NaN                        NaN     \checkmark
# 23                                                    NaN     \checkmark
# 24                                                    NaN     \checkmark
# 25                                                    NaN     \checkmark
# 26                                                    NaN
# 27                                       NaN          NaN     \checkmark
# 28   \checkmark                                       NaN     \checkmark
# 29                                                    NaN
# 30                                                    NaN     \checkmark
# 31                                                    NaN     \checkmark
# 32                                                    NaN     \checkmark
# 33                                                    NaN     \checkmark
# 34                                                    NaN     \checkmark
# 35                                                    NaN     \checkmark
# 36                                                    NaN
# 37                                                    NaN
# 38                                                    NaN     \checkmark
# 39   \checkmark                                       NaN     \checkmark
# 40                                                    NaN     \checkmark
# 41                                                    NaN     \checkmark
# 42          nan           nan           nan           NaN     \checkmark
# 43                                                    NaN     \checkmark
# 44                                                    NaN     \checkmark
# 45                                                    NaN     \checkmark
# 46                                                    NaN     \checkmark
# 47          nan           nan           nan           NaN     \checkmark
# 48          nan           nan           nan           NaN         \xmark
# 49          nan           nan           nan           NaN         \xmark
# 50          nan           nan           nan           NaN         \xmark
# 51          nan           nan           nan           NaN     \checkmark
# 52          nan           nan           nan           NaN     \checkmark
# 53          nan           nan           nan           NaN     \checkmark
# 54          nan           nan           nan           NaN     \checkmark
# 55          nan           nan           nan           NaN         \xmark
# 56          nan           nan           nan           NaN     \checkmark
# 57          nan           nan           nan           NaN     \checkmark
# 58          nan           nan           nan           NaN     \checkmark
# 59          nan           nan           nan           NaN         \xmark
# 60          nan           nan           nan           NaN     \checkmark
# 61          nan           nan           nan           NaN     \checkmark
# 62          nan           nan           nan           NaN     \checkmark
# 63          nan           nan           nan           NaN         \xmark
# 64          nan           nan           nan           NaN         \xmark
# 65          nan           nan           nan           NaN         \xmark
# 66          nan           nan           nan           NaN     \checkmark
# 67          nan           nan           nan           NaN     \checkmark
# 68          nan           nan           nan           NaN     \checkmark
# 69          nan           nan           nan           NaN         \xmark
# 70          nan           nan           nan           NaN     \checkmark
# 71          nan           nan           nan           NaN     \checkmark
# 72          nan           nan           nan           NaN     \checkmark
# 73          nan           nan           nan           NaN         \xmark
# 74          nan           nan           nan           NaN     \checkmark
# 75          nan           nan           nan           NaN     \checkmark
# 76          nan           nan           nan           NaN     \checkmark
# 77                                                    NaN
# 78          nan           nan           nan           NaN     \checkmark
# 79          nan           nan           nan           NaN     \checkmark
# 80          nan           nan           nan           NaN     \checkmark
# 81          nan           nan           nan           NaN     \checkmark
# 82          nan           nan           nan           NaN     \checkmark
# 83          nan           nan           nan           NaN     \checkmark
# 84          nan           nan           nan           NaN     \checkmark
# 85          nan           nan           nan           NaN     \checkmark
# 86          nan           nan    \checkmark           NaN     \checkmark
# 87          nan           nan    \checkmark           NaN     \checkmark
# 88          nan           nan    \checkmark           NaN     \checkmark
# 89          nan           nan    \checkmark           NaN         \xmark
# 90          nan           nan    \checkmark           NaN     \checkmark
# 91          nan           nan           nan           NaN     \checkmark
# 92          nan           nan           nan           NaN     \checkmark

# %% [markdown]
# df.sort_values(by=['  math model type  ','Model '], inplace=True)

# %%
df.set_index('Model ', drop=True, inplace=True)

# %%
df.style.to_latex("2023-dotson-prelim/docs/tables/esom_database.tex", hrules=True)
