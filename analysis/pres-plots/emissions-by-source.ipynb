# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Life-cycle_greenhouse_gas_emissions_of_energy_sources')[-2]
df.columns = ['Technology', 'Class', 'gCO2eq/kWh']

# %%
df.groupby(by='Technology').describe()
# Out:
#             gCO2eq/kWh                                                   \
#                  count   mean         std    min     25%    50%     75%
# Technology
# CSP                2.0   32.0   14.142136   22.0   27.00   32.0   37.00
# Hard coal          6.0  630.0  336.986647  280.0  340.00  610.0  925.00
# Hydro              2.0   80.5   98.287843   11.0   45.75   80.5  115.25
# Natural gas        2.0  280.0  212.132034  130.0  205.00  280.0  355.00
# Nuclear            1.0    5.1         NaN    5.1    5.10    5.1    5.10
# PV                 6.0   21.0   12.473973   11.0   12.50   14.5   31.50
# Wind               3.0   13.0    1.000000   12.0   12.50   13.0   13.50
#
#
#                 max
# Technology
# CSP            42.0
# Hard coal    1000.0
# Hydro         150.0
# Natural gas   430.0
# Nuclear         5.1
# PV             37.0
# Wind           14.0

# %%
import matplotlib as mpl
mpl.use("pgf")
plt.rcParams['pgf.texsystem'] = 'pdflatex'
plt.rcParams['text.usetex'] = True
plt.rcParams['pgf.rcfonts'] = False
plt.rcParams['figure.edgecolor'] = 'k'
plt.rcParams['figure.facecolor'] = 'w'
plt.rcParams['savefig.dpi'] = 400
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['font.family'] = "serif"

plt.figure(figsize=(8, 6), facecolor='w')

# plot a bar chart
ax = sb.barplot(x="Technology", y="gCO2eq/kWh", data=df, estimator=np.mean, 
                errorbar=('ci',65), capsize=.2, color='lightblue')
ax.set_ylabel(r'Lifecycle Emissions $\left[\frac{{gCO}_{2}eq}{kWh}\right]$',fontsize=16)
ax.set_xlabel('')
ax.grid(alpha=0.3)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=20)
plt.tight_layout()
plt.show()
plt.savefig("../../docs/figures/emissions-by-source.pgf")
# Out:
# /var/folders/6h/g412p7x53jbcqr_x5sy9z8th0000gn/T/ipykernel_58931/1773402969.py:23: UserWarning: FigureCanvasPgf is non-interactive, and thus cannot be shown
#   plt.show()
