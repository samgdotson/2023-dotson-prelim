# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Life-cycle_greenhouse_gas_emissions_of_energy_sources')[-2]
df.columns = ['Technology', 'Class', 'gCO2eq/kWh']

# %%
df.groupby(by='Technology').describe()
# Out:
#             gCO2eq/kWh                                                   \
#                  count   mean         std    min     25%    50%     75%
# Technology
# CSP                2.0   32.0   14.142136   22.0   27.00   32.0   37.00
# Hard coal          6.0  630.0  336.986647  280.0  340.00  610.0  925.00
# Hydro              2.0   80.5   98.287843   11.0   45.75   80.5  115.25
# Natural gas        2.0  280.0  212.132034  130.0  205.00  280.0  355.00
# Nuclear            1.0    5.1         NaN    5.1    5.10    5.1    5.10
# PV                 6.0   21.0   12.473973   11.0   12.50   14.5   31.50
# Wind               3.0   13.0    1.000000   12.0   12.50   13.0   13.50
#
#
#                 max
# Technology
# CSP            42.0
# Hard coal    1000.0
# Hydro         150.0
# Natural gas   430.0
# Nuclear         5.1
# PV             37.0
# Wind           14.0

# %%
plt.arrow?

# %%
import matplotlib as mpl
# mpl.use("pgf")
# plt.rcParams['pgf.texsystem'] = 'pdflatex'
# plt.rcParams['text.usetex'] = True
# plt.rcParams['pgf.rcfonts'] = False
plt.rcParams['figure.edgecolor'] = 'k'
plt.rcParams['figure.facecolor'] = 'w'
plt.rcParams['savefig.dpi'] = 400
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['font.family'] = "serif"

plt.figure(figsize=(8, 6), facecolor='w')

# plot a bar chart
ax = sb.barplot(x="Technology", y="gCO2eq/kWh", data=df, estimator=np.mean, 
                errorbar=('ci',65), capsize=.2, color='lightblue')
ax.set_ylabel(r'Lifecycle Emissions $\left[\frac{{gCO}_{2}eq}{kWh}\right]$',fontsize=16)
ax.set_xlabel('')
ax.grid(alpha=0.3)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=20)
plt.tight_layout()
# ax.arrow(x=1.25,y=600, dx=0.75*3, dy=-400, width=0.4, shape='full', head_length=40)
# prop = dict(facecolor='black', shrink=0.05)
prop = dict(arrowstyle="<|-,head_width=0.4,head_length=0.8,tail_width=0.4",
            shrinkA=0,shrinkB=0,facecolor='k')
ax.annotate("", xy=(1.24,600),xycoords='data', xytext=(4.25,200), textcoords='data', arrowprops=prop)
plt.show()
# plt.savefig("../../docs/figures/emissions-by-source.pgf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 27
#      23 # ax.arrow(x=1.25,y=600, dx=0.75*3, dy=-400, width=0.4, shape='full', head_length=40)
#      24 # prop = dict(facecolor='black', shrink=0.05)
#      25 prop = dict(arrowstyle="<|-,head_width=0.4,head_length=0.8,tail_width=0.4",
#      26             shrinkA=0,shrinkB=0,facecolor='k')
# ---> 27 ax.annotate("", xy=(1.24,600),xycoords='data', xytext=(4.25,200), textcoords='data', arrowprops=prop)
#      28 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:711, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     706 @_docstring.dedent_interpd
#     707 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     708              arrowprops=None, annotation_clip=None, **kwargs):
#     709     # Signature must match Annotation. This is verified in
#     710     # test_annotate_signature().
# --> 711     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     712                          textcoords=textcoords, arrowprops=arrowprops,
#     713                          annotation_clip=annotation_clip, **kwargs)
#     714     a.set_transform(mtransforms.IdentityTransform())
#     715     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/text.py:1840, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1837             _api.warn_deprecated(
#    1838                 "3.8", name="the (unused) 'frac' key in 'arrowprops'")
#    1839             arrowprops.pop("frac")
# -> 1840     self.arrow_patch = FancyArrowPatch((0, 0), (1, 1), **arrowprops)
#    1841 else:
#    1842     self.arrow_patch = None
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/patches.py:4169, in FancyArrowPatch.__init__(self, posA, posB, path, arrowstyle, connectionstyle, patchA, patchB, shrinkA, shrinkB, mutation_scale, mutation_aspect, **kwargs)
#    4165 self.shrinkB = shrinkB
#    4167 self._path_original = path
# -> 4169 self.set_arrowstyle(arrowstyle)
#    4171 self._mutation_scale = mutation_scale
#    4172 self._mutation_aspect = mutation_aspect
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/patches.py:4293, in FancyArrowPatch.set_arrowstyle(self, arrowstyle, **kwargs)
#    4290 if arrowstyle is None:
#    4291     return ArrowStyle.pprint_styles()
#    4292 self._arrow_transmuter = (
# -> 4293     ArrowStyle(arrowstyle, **kwargs)
#    4294     if isinstance(arrowstyle, str) else arrowstyle)
#    4295 self.stale = True
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/patches.py:2246, in _Style.__new__(cls, stylename, **kwargs)
#    2243 except ValueError as err:
#    2244     raise ValueError(
#    2245         f"Incorrect style argument: {stylename!r}") from err
# -> 2246 return _cls(**{**_args, **kwargs})
#
# TypeError: ArrowStyle._Curve.__init__() got an unexpected keyword argument 'tail_width'
